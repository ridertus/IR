# %%
import pandas as pd
import re

# %%
recipes_df = pd.read_csv('./data/recipes.csv')
comment_df = pd.read_csv('./data/reviews.csv')

# %%
comment_df.dropna(inplace=True)
recipes_df.dropna(inplace=True)

# %%
indexImage = recipes_df[( recipes_df['Images'] == 'character(0)')].index
recipes_df.drop(indexImage, inplace=True)

indexImage = recipes_df[(recipes_df['Images'] == 'c("")' )].index
recipes_df.drop(indexImage, inplace=True)

# %%
recipes_df.to_csv('./out/recipes.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ### Insert to database

# %%
import pymongo

# %%
import re

def convert_to_array(string):
    # Remove leading and trailing quotation marks if present
    string = string.strip('"\'')

    # Check if the input string is empty
    if not string:
        return []  # Return an empty list if the input is empty

    # Check if the input string contains "c(" and ")"
    if 'c(' in string and ')' in string:
        # Use regular expression to split the string at commas, considering quotes and spaces
        array = re.findall(r'"[^"]*"|[^",\s]+', string)

        array[:] = (value for value in array if value != '')        
        array[:] = (value for value in array if value != 'c(')        
        array[:] = (value for value in array if value != ')')        
        array[:] = (value for value in array if value != ' ')        
        # Remove any leading or trailing whitespace from each element
        array = [s.strip('"') for s in array]
        return list(set(array))
    else:
        return list(set([string]))  # Return the input string as a single-element list

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")
db = client["food"] 
col = db["recipeDIP"] 

cleaned_recipe_collection = db['cleaned_recipe']

for recipe in col.find({}): 
    cleaned_recipe = {
        'RecipeId': recipe['RecipeId'] ,
        'Name': recipe['Name']  ,
        'AuthorId': recipe['AuthorId'] ,
        'AuthorName': recipe['AuthorName'] ,
        'CookTime':  recipe['CookTime'] ,
        'PrepTime':  recipe['PrepTime'],
        'TotalTime': recipe['TotalTime'] ,
        'DatePublished': recipe['DatePublished'] ,
        'Description': recipe['Description'],
        'Images': convert_to_array(recipe['Images']),
        'RecipeCategory': recipe['RecipeCategory'],
        'Keywords': convert_to_array(recipe['Keywords']),
        'RecipeIngredientQuantities': convert_to_array(recipe['RecipeIngredientQuantities']),
        'RecipeIngredientParts':  convert_to_array(recipe['RecipeIngredientParts']),
        'AggregatedRating': recipe['AggregatedRating'],
        'Calories': recipe['Calories'],
        'FatContent': recipe['FatContent'],
        'SaturatedFatContent': recipe['SaturatedFatContent'],
        'CholesterolContent': recipe['CholesterolContent'],
        'SodiumContent': recipe['SodiumContent'],
        'CarbohydrateContent': recipe['CarbohydrateContent'],
        'FiberContent': recipe['FiberContent'],
        'SugarContent': recipe['SugarContent'],
        'ProteinContent': recipe['ProteinContent'],
        'RecipeServings': recipe['RecipeServings'],
        'RecipeYield': recipe['RecipeYield'],
        'RecipeInstructions':  convert_to_array(recipe['RecipeInstructions']),
    }

    # print(cleaned_recipe)
    cleaned_recipe_collection.insert_one(cleaned_recipe)

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")
db = client["food"] 
col = db["cleaned_recipe"] 
cleaned_recipe_collection = db['cleaned_recipe']

# %% [markdown]
# ### Try Query

# %%
myquery = { "RecipeCategory": "Quick Breads" }
results = cleaned_recipe_collection.find(myquery).limit(5)

for match in results:
    print(match)
# Out:
# {'_id': ObjectId('65f8121ae3777c5d4262d1cb'), 'RecipeId': 153, 'Name': 'Amish Friendship Bread and Starter', 'AuthorId': 1540, 'AuthorName': 'gowiththefro', 'CookTime': 'PT1H10M', 'PrepTime': 'PT0S', 'TotalTime': 'PT1H10M', 'DatePublished': datetime.datetime(1999, 9, 6, 21, 41), 'Description': "Many recipes have been posted for the Amish bread, but none have included the starter, so I thought I'd send this along.  Happy baking!  Amish Friendship Bread and Starter", 'Images': ['https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/15/3/picldR2s3.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/15/3/picjFhmLD.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/15/3/picqwMJR8.jpg'], 'RecipeCategory': 'Quick Breads', 'Keywords': ['Breads', '< 4 Hours', 'Easy', 'Oven'], 'RecipeIngredientQuantities': ['1 1/2', '2', '1/2', '1', '3'], 'RecipeIngredientParts': ['eggs', 'instant vanilla pudding', 'flour', 'vanilla extract', 'sugar', 'cinnamon', 'salt', 'baking soda', 'milk', 'baking powder'], 'AggregatedRating': 5, 'Calories': 615.9, 'FatContent': 21.3, 'SaturatedFatContent': 4, 'CholesterolContent': 42.4, 'SodiumContent': 374.9, 'CarbohydrateContent': 100, 'FiberContent': 2.3, 'SugarContent': 65.2, 'ProteinContent': 8.5, 'RecipeServings': 'NA', 'RecipeYield': '16-18 squares', 'RecipeInstructions': ["It's now ready to use to make the bread.", 'On days 19, 20, and 21, stir.', 'Place ONE cup each sugar, milk, and flour in large glass or plastic bowl.', 'On day 18 do nothing.', 'On day 22, add 1 cup sugar, 1 cup milk, and 1 cup flour, and stir again.', 'Add to liquid mixture and stir thoroughly.', 'Pour into two large well-greased 9x5 inch loaf pans, or one Bundt pan, that have been sprinkled with a mixture of cinnamon, sugar, and flour.', 'Give away two cups of the starter to two friends, use one to make the bread, and keep one to keep the starter going.  When you give away a cup of the starter, give these directions for keeping it going:  Do not refrigerate; Do not use metal spoon or metal bowl; Do not cover tightly, cover loosely with plastic wrap.', 'On day 27, add 1 cup milk, 1 cup flour, and 1 cup sugar and stir.', 'Sprinkle more cinnamon and sugar on the tops of the unbaked loaves (or cake).  Bake at 325F for one hour or until done.', 'AMISH FRIENDSHIP BREAD:  Mix oil, eggs, and vanilla with the starter mix.', 'In a separate bowl, mix flour, sugar, baking powder, cinnamon, salt, baking soda, vanilla pudding mix, and nuts.', 'On days 23, 24, 25, and 26 stir.', 'Cover lightly with plastic wrap and set on your counter at room temperature. Stir with a wooden spoon everyday for 17 days.']}
# {'_id': ObjectId('65f8121ae3777c5d4262d1ea'), 'RecipeId': 185, 'Name': 'Cola Fruit and Date Loaf', 'AuthorId': 125579, 'AuthorName': 'GrandmaIsCooking', 'CookTime': 'PT1H', 'PrepTime': 'PT50M', 'TotalTime': 'PT1H50M', 'DatePublished': datetime.datetime(1999, 8, 23, 12, 41), 'Description': '--Adopted Recipe--  The original submitter says that this fruity loaf showed up in Coke and Seven-Up cookbooks. The recipe was adapted  from &quot;Cooking With Coke&quot; - a publication of the Coca Cola Company.  Be sure to make a day ahead of time, because it is best the next day.', 'Images': ['https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/18/5/picgrPBKe.jpg'], 'RecipeCategory': 'Quick Breads', 'Keywords': ['Healthy', 'Oven', 'Breads', 'Fruit', 'Low Cholesterol', '< 4 Hours', 'Weeknight'], 'RecipeIngredientQuantities': ['1', '1/2', '1 1/4', '2'], 'RecipeIngredientParts': ['pecans', 'flour', 'vanilla extract', 'brown sugar', 'egg', 'cinnamon', 'lemon rind', 'dates', 'baking soda', 'baking powder'], 'AggregatedRating': 5, 'Calories': 267, 'FatContent': 6.2, 'SaturatedFatContent': 0.7, 'CholesterolContent': 17.6, 'SodiumContent': 150, 'CarbohydrateContent': 51.4, 'FiberContent': 2.6, 'SugarContent': 32.2, 'ProteinContent': 3.6, 'RecipeServings': 12, 'RecipeYield': 'NA', 'RecipeInstructions': ['Preheat oven to 350 Fahrenheit.', 'Chop dates.', 'Store overnight before slicing.', 'Stir in sugar and oil.  Cool while preparing other ingredients.', 'Stir dry ingredients together and add to cola mixture.  Stir in egg, extract and nuts.', 'Generously grease a 9 by 5 inch loaf pan.', 'Heat cola to boiling.  Remove from heat and stir in dates, mixing very well.', 'Spoon batter into pan.  Bake about 1 hour until cake tests done.  Cool on a rack for 20 minutes then remove from pan and wrap.']}
# {'_id': ObjectId('65f8121ae3777c5d4262d1ef'), 'RecipeId': 191, 'Name': 'Chilies Corn Muffins', 'AuthorId': 1530, 'AuthorName': 'Carole Reu', 'CookTime': 'PT25M', 'PrepTime': 'PT35M', 'TotalTime': 'PT1H', 'DatePublished': datetime.datetime(1999, 9, 6, 4, 52), 'Description': 'Make and share this Chilies Corn Muffins recipe from Food.com.', 'Images': ['character(0)'], 'RecipeCategory': 'Quick Breads', 'Keywords': ['Oven', 'Vegetable', 'Breads', 'Peppers', '< 60 Mins'], 'RecipeIngredientQuantities': ['1 1/2', '1/4', '1/2', '4', '1', '3'], 'RecipeIngredientParts': ['all-purpose flour', 'cornmeal', 'green chilies', 'egg', 'sugar', 'soymilk', 'salt', 'brown sugar', 'baking powder', 'skim milk'], 'AggregatedRating': 5, 'Calories': 163.6, 'FatContent': 5.3, 'SaturatedFatContent': 0.8, 'CholesterolContent': 17.8, 'SodiumContent': 155.6, 'CarbohydrateContent': 26.2, 'FiberContent': 0.9, 'SugarContent': 9.2, 'ProteinContent': 3.1, 'RecipeServings': 12, 'RecipeYield': 'NA', 'RecipeInstructions': ['Make well in dry ingredients.', 'Let cool in pan 5 minutes, them loosen edges and turn out on rack and cool completely.', 'Add milk  mixture and stir until just blended.', 'In medium bowl, whisk flour, cornmeal, both sugars, baking powder and salt.  In medium  bowl, mix remaining ingredients.', 'Bake 15 to 20 minutes, or until top springs back when lightly pressed.', 'Divide batter among prepared muffin cups.', 'Preheat oven to 400.', 'Spray a standard muffin pan with cooking spray.']}
# {'_id': ObjectId('65f8121ae3777c5d4262d206'), 'RecipeId': 215, 'Name': 'Crock Pot Chocolate Zucchini Nut Bread', 'AuthorId': 39547, 'AuthorName': 'Julesong', 'CookTime': 'PT3H', 'PrepTime': 'PT10M', 'TotalTime': 'PT3H10M', 'DatePublished': datetime.datetime(1999, 8, 10, 6, 53), 'Description': "This is an adopted recipe.  Directions refer to a &quot;bread insert.&quot;  If you don't have the manufacturer's baking insert with a lid, you can use an 2 pound metal coffee can. Use a double thickness of paper towels as a can cover.", 'Images': ['character(0)'], 'RecipeCategory': 'Quick Breads', 'Keywords': ['Nuts', 'Vegetable', 'Breads', 'Fruit', '< 4 Hours', 'Weeknight'], 'RecipeIngredientQuantities': ['1/3', '2', '1/2', '1', '3', '1 1/4'], 'RecipeIngredientParts': ['eggs', 'vanilla', 'shortening', 'flour', 'walnuts', 'sugar', 'zucchini', 'baking soda', 'milk'], 'AggregatedRating': 5, 'Calories': 2867.8, 'FatContent': 120.7, 'SaturatedFatContent': 32.5, 'CholesterolContent': 429.4, 'SodiumContent': 1447.9, 'CarbohydrateContent': 414.9, 'FiberContent': 18, 'SugarContent': 205, 'ProteinContent': 47.4, 'RecipeServings': 'NA', 'RecipeYield': '1 loaf', 'RecipeInstructions': ['Cream sugar and shortening in mixer, beat in eggs one at a time, add vanilla.  Add everything else and mix thoroughly.', 'Possible modifications:  no cocoa; substitute 2 tsp cinnamon and 1 tsp nutmeg for cocoa; substitute 1 cup brown sugar for the white sugar.', "Let stand until it's medium cool to the touch before unmolding.  Serve with butter.  You can also dust the bread with powdered sugar.", 'Pour into a greased crock pot bread insert.  Cook 3 hours on high, or until the bread tests done with a wooden pick.']}
# {'_id': ObjectId('65f8121ae3777c5d4262d20b'), 'RecipeId': 220, 'Name': 'Chocolate Zucchini Bread', 'AuthorId': 1604, 'AuthorName': 'itsjustme', 'CookTime': 'PT1H', 'PrepTime': 'PT25M', 'TotalTime': 'PT1H25M', 'DatePublished': datetime.datetime(1999, 8, 7, 9, 18), 'Description': 'Make and share this Chocolate Zucchini Bread recipe from Food.com.', 'Images': ['https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/picuHKLvl.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/pic6dBbjd.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/Odj8qst8T1eVOImGOCWg_image.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/picVl9WPD.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/2rp90sY9Q96l93ATXIsR_zucchinnibread1%20(1%20of%201).jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/zrkZ5Dc3RdyIotK1LwV7_IMG_4718.JPG', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/V4O52EGNQlCwno2EDOa4_zucchinnibread3%20(1%20of%201).jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/pic0sEwXu.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/ox0bM5LFTvamSUZZrvGJ_zucchinnibread2%20(1%20of%201).jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/picAqmOmd.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/picdChvnL.jpg', 'https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/22/0/NiKUyiO5Tt2T3IQzUpRi_IMG_4717.JPG', 'https://img.sndimg.com/food/image/upload/v1/img/feed/220/WgGTZM7mSLeMEnLraslw_IMG_4717.JPG'], 'RecipeCategory': 'Quick Breads', 'Keywords': ['Sweet', 'Oven', 'Vegetable', 'Breads', '< 4 Hours', 'Weeknight'], 'RecipeIngredientQuantities': ['2 1/2', '1/4', '2', '1/2', '1', '3'], 'RecipeIngredientParts': ['all-purpose flour', 'eggs', 'vanilla extract', 'sugar', 'cinnamon', 'zucchini', 'salt', 'baking soda', 'baking powder'], 'AggregatedRating': 5, 'Calories': 501.2, 'FatContent': 24.2, 'SaturatedFatContent': 3.7, 'CholesterolContent': 55.8, 'SodiumContent': 392.8, 'CarbohydrateContent': 67.6, 'FiberContent': 2.7, 'SugarContent': 40.9, 'ProteinContent': 6.3, 'RecipeServings': 10, 'RecipeYield': '2 loaves', 'RecipeInstructions': ['Stir in zucchini.', 'Pour into two greased 8x4x3-inch loaf pans.', 'Bake at 350°F for 1 hour or until bread tests done.  Makes 2 loaves.', 'Combine dry ingredients; add to zucchini mixture and mix well.', 'In a mixing bowl, beat eggs, oil, sugar and vanilla.']}

# %% [markdown]
# ### Put the recipe into elasticsearch

# %%
from elasticsearch import Elasticsearch
import json
from bson import ObjectId
from elasticsearch import helpers

# %%
class ElasticIndexer:
    def __init__(self):
        self.es_client = Elasticsearch('https://localhost:9200', basic_auth=("elastic", "azjt*71kG2zv+cVkTTD8"),
                    ca_certs="./http_ca.crt")
        self.mongo_client = pymongo.MongoClient("mongodb://localhost:27017")
        self.mongo_collection = self.mongo_client['food']['cleaned_recipe']

    def run_indexer(self):
        self.es_client.indices.create(index='recipe', ignore=400)
        self.es_client.indices.delete(index='recipe', ignore=[400, 404])
        actions = []
        
        for doc in self.mongo_collection.find({}):
            _id = str(doc['_id'])
            del doc["_id"]
            action = {
                "_index": 'recipe',
                "_source": doc
            }
            actions.append(action)

        response = helpers.bulk(self.es_client, actions)
        return response

# %%
es = ElasticIndexer()
es.run_indexer()
# Out:
# C:\Users\rider\AppData\Local\Temp\ipykernel_144772\4262637330.py:9: DeprecationWarning: Passing transport options in the API method is deprecated. Use 'Elasticsearch.options()' instead.
#   self.es_client.indices.create(index='recipe', ignore=400)
# C:\Users\rider\AppData\Local\Temp\ipykernel_144772\4262637330.py:10: DeprecationWarning: Passing transport options in the API method is deprecated. Use 'Elasticsearch.options()' instead.
#   self.es_client.indices.delete(index='recipe', ignore=[400, 404])
# (15462, [])

# %%
es_client = Elasticsearch('https://localhost:9200', basic_auth=("elastic", "azjt*71kG2zv+cVkTTD8"),
                    ca_certs="./http_ca.crt")

# %%
query = {
    "query_string": {
        "query": "Sweet Rolls Easy"
    }
}

results = es_client.search(index='recipe', query=query)
results_df = pd.DataFrame([[hit["_source"]['Name'], hit["_source"]['Keywords'], hit["_source"]
['RecipeIngredientParts'], hit["_score"]] for hit in results['hits']['hits']], columns=['Name', 'Keywords', 'Ingredient', 
'score'])
results_df
# Out:
#                                              Name  \
# 0                             Breakfast Egg Rolls
# 1                             Honey Orange Butter
# 2                             Easy Crunchy Toffee
# 3                 The Best Sweet Potato Casserole
# 4                                  Sweet Kielbasa
# 5           Hawaiian Bread Ham &amp; Cheese Rolls
# 6        Sweet Potato Pancakes With Caramel Sauce
# 7                                     Sweet Rolls
# 8   Mini Cajun Burgers With Easy R&eacute;moulade
# 9  Coconut Shrimp With Guava Sweet and Sour Sauce
#
#                                             Keywords  \
# 0                                [Brunch, < 60 Mins]
# 1  [Beginner Cook, Inexpensive, < 15 Mins, Low Pr...
# 2            [Easy, Beginner Cook, For Large Groups]
# 3  [Beginner Cook, Inexpensive, Potato, Kid Frien...
# 4                  [Potluck, For Large Groups, Meat]
# 5                                 [For Large Groups]
# 6  [< 30 Mins, Potato, Yam/Sweet Potato, Vegetabl...
# 7  [Sweet, Kid Friendly, Thanksgiving, For Large ...
# 8                                 [Cajun, < 30 Mins]
# 9  [< 30 Mins, Summer, Polynesian, Fruit, Weeknight]
#
#                                           Ingredient      score
# 0  [onion, green pepper, eggs, cheese, water, mil...  13.042132
# 1                         [honey, butter, margarine]  12.088933
# 2             [butter, chocolate chips, brown sugar]  11.833335
# 3  [vanilla, butter, salt, brown sugar, eggs, wal...  10.931320
# 4  [kielbasa, brown sugar, water, apple cider, on...  10.792521
# 5  [butter, prepared yellow mustard, deli ham, sw...  10.752760
# 6  [butter, canned sweet potatoes, ground allspic...  10.670794
# 7  [active dry yeast, butter, ground cinnamon, sa...  10.655209
# 8  [creole mustard, sausage, green leaf lettuce, ...  10.290481
# 9  [coconut flakes, panko breadcrumbs, white vine...  10.101153

# %% [markdown]
# ### Recommendations

# %%
# Get top 5 similar to the selected dish

query = { 
   "more_like_this":{
    # Breakfast Eggcake ID:'65d5e4928598535be43ec668' 
    "fields":["Name", "Keywords", "RecipeIngredientParts", "RecipeCategory"],"like":[{"_id": '65d5e4928598535be43ec668'}],"min_term_freq":1,"min_doc_freq":5,"max_query_terms":20
    }
}

results = es_client.search(index='recipe', query=query, size=5)
results_df = pd.DataFrame([[hit["_source"]['Name'], hit["_source"]['Keywords'], hit["_source"]
['RecipeIngredientParts'], hit["_score"]] for hit in results['hits']['hits']], columns=['Name', 'Keywords', 'Ingredient', 
'score'])
results_df
# Out:
# Empty DataFrame
# Columns: [Name, Keywords, Ingredient, score]
# Index: []

# %% [markdown]
# ### Personalized by interestedCategory

# %%
users = db['users']

user = users.find({'_id': ObjectId('65f017e507c1a9b66d854764')})
user_df = pd.DataFrame(user)

# %%
user_df['interestedCategory'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 user_df['interestedCategory'][0]
#
# File c:\Users\rider\anaconda3\envs\IR\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\rider\anaconda3\envs\IR\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'interestedCategory'

# %%
query_term="pancoke"
query={
            
                "query":{
                    "dis_max": {
                        "queries": [
                            { "match": { "Name": query_term }},
                            { "match": { "RecipeIngredientParts": query_term }},
                            { "match": { "RecipeInstructions": query_term }},
                        ],
                        "tie_breaker": 0.3
                    },
                },
                
            
        }

results = es_client.search(index='recipe', body=query, size=10000)
results_df = pd.DataFrame([[hit["_source"]['Name'], hit["_source"]['Keywords'], hit["_source"]
['RecipeIngredientParts'], hit["_score"]] for hit in results['hits']['hits']], columns=['Name', 'Keywords', 'Ingredient', 
'score'])
results
# Out:
# C:\Users\rider\AppData\Local\Temp\ipykernel_104456\2217797107.py:18: DeprecationWarning: Received 'size' via a specific parameter in the presence of a 'body' parameter, which is deprecated and will be removed in a future version. Instead, use only 'body' or only specific parameters.
#   results = es_client.search(index='recipe', body=query, size=10000)
# ObjectApiResponse({'took': 5, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 0, 'relation': 'eq'}, 'max_score': None, 'hits': []}})

# %% [markdown]
# ### Score by weight

# %%
query = {
    "dis_max": {
        "queries": [
            {
                "more_like_this": {
                    "fields": ["Name", "Keywords", "RecipeIngredientParts", "RecipeCategory"],
                    # Anzac Biscuits
                    "like": [{"_id": "65d5e48d8598535be43eb8f3"}],
                    "min_term_freq": 1,
                    "min_doc_freq": 5,
                    "max_query_terms": 20,
                    "boost": 0.2
                }
            },
            {
                "more_like_this": {
                    "fields": ["Name", "Keywords", "RecipeIngredientParts", "RecipeCategory"],
                    # TOFU KEBAB
                    "like": [{"_id": "65d5e48d8598535be43eb8f1"}],
                    "min_term_freq": 1,
                    "min_doc_freq": 5,
                    "max_query_terms": 20,
                    "boost": 0.5
                }
            }
            #   More Recipe in bookmarks 
            #   Does boost make sense or not?
        ]
    }
}


results = es_client.search(index='recipe', query=query, size=15)
results_df = pd.DataFrame([[hit["_source"]['Name'], hit["_source"]['Keywords'], hit["_source"]
['RecipeIngredientParts'], hit["_score"]] for hit in results['hits']['hits']], columns=['Name', 'Keywords', 'Ingredient', 
'score'])
results_df
# Out:
#                                                  Name  \
# 0                       Healthy Vegetable Tofu Kebabs
# 1                          Tofu and Bok Choy Stir Fry
# 2                          Tasty Tofu Veggie Scramble
# 3                       Pf Chang's Tofu Lettuce Wraps
# 4            Spicy &quot;Barbecued&quot; Tofu Burgers
# 5                                       Barbecue Tofu
# 6                             Vegan Baked Tofu Strips
# 7   Sydney Broccoli, Red Pepper &amp; Tofu Stir Fr...
# 8                                Chinese Bourbon Tofu
# 9                            Tofu  Fish (Or Not-Fish)
# 10                                   Tofu Bourguignon
# 11  Dofu Cai Mian (Tofu Vegetable Noodle Soup, Two...
# 12                                 Tofu Buffalo Wings
# 13                                  Best Tofu Pot Pie
# 14     Tempura Beet Rollatini With Balsamic Gastrique
#
#                                              Keywords  \
# 0              [< 30 Mins, Peppers, Vegetable, Beans]
# 1   [Vegan, < 15 Mins, Chinese, Vegetable, Low Cho...
# 2   [Vegan, < 30 Mins, Lactose Free, Free Of..., E...
# 3                    [Vegan, Asian, Beans, < 60 Mins]
# 4   [Soy/Tofu, Inexpensive, Broil/Grill, Vegetable...
# 5   [Beginner Cook, Inexpensive, Brunch, Vegan, Su...
# 6   [Vegan, Microwave, Free Of..., < 60 Mins, Potl...
# 7   [Soy/Tofu, From Scratch, Peppers, < 30 Mins, S...
# 8   [Soy/Tofu, Vegan, Chinese, Low Cholesterol, As...
# 9   [Beginner Cook, Inexpensive, < 30 Mins, Free O...
# 10  [Vegan, Vegetable, European, Low Cholesterol, ...
# 11  [Soy/Tofu, Inexpensive, Vegan, < 30 Mins, Chin...
# 12  [Soy/Tofu, Vegan, Low Cholesterol, < 4 Hours, ...
# 13  [Soy/Tofu, Savory, Vegan, Inexpensive, Kid Fri...
# 14  [Vegan, Vegetable, European, Fruit, Nuts, Asia...
#
#                                            Ingredient      score
# 0   [firm tofu, salt, green pepper, button mushroo...  32.092094
# 1   [bok choy, low sodium soy sauce, extra firm to...  24.713129
# 2   [garlic powder, green bell pepper, low sodium ...  23.104267
# 3   [garlic, brown sugar, extra firm tofu, water, ...  23.036478
# 4   [pickle, barbecue sauce, lemon-pepper seasonin...  22.060250
# 5   [firm tofu, onion powder, blackstrap molasses,...  21.835814
# 6   [panko breadcrumbs, sea salt, poultry seasonin...  21.595547
# 7   [extra firm tofu, scallions, reduced sodium so...  19.839397
# 8   [garlic, low sodium soy sauce, brown sugar, ex...  19.690624
# 9   [firm tofu, nori, paprika, wheat germ, polenta...  19.055569
# 10  [firm tofu, salt, shallots, tomato paste, garl...  17.661283
# 11  [frozen carrots, firm tofu, spinach, water che...  17.139599
# 12  [garlic powder, barbecue sauce, salt, extra fi...  16.467728
# 13  [garlic powder, firm tofu, celery, peas, salt,...  15.866154
# 14  [firm tofu, Cashew Cream(Regular and Thick), s...  15.780364

# %% [markdown]
# ### Not interested topic?

# %%
un_prefer = set(user['uninterestedCategory'])   # boost down
prefer = set(user['interestedCategory'])  - un_prefer # boost up

query = {
    "dis_max": {
        "queries": [
            {
                "boosting": {
                    "positive" : {
                        "match": {"Keywords": ' '.join(prefer)},
                        # "term": {"_id": "65d5e49a8598535be43ee02b"}
                    },
                    "negative": {
                        "match": {"Keywords": ' '.join(un_prefer)}
                    },
                    "negative_boost": 0.5
                }
            },
            {
                "more_like_this": {
                    "fields": ["Name", "Keywords", "RecipeIngredientParts", "RecipeCategory"],
                    # TOFU KEBAB
                    "like": [{"_id": "65d5e48d8598535be43eb8f1"}],
                    "min_term_freq": 1,
                    "min_doc_freq": 5,
                    "max_query_terms": 20,
                    "boost": 1.1
                }
            },
                        {
                "more_like_this": {
                    "fields": ["Name", "Keywords", "RecipeIngredientParts", "RecipeCategory"],
                    # Anzac Biscuits
                    "like": [{"_id": "65d5e48d8598535be43eb8f3"}],
                    "min_term_freq": 1,
                    "min_doc_freq": 5,
                    "max_query_terms": 20,
                    "boost": 1.1
                }
            },
            # {
            #     "query_string": {
            #         "query": ' '.join(prefer),
            #         "boost": 1.2
            #     }
            # }
            # {
            #     "query_string": {
            #         "query": ' '.join(un_prefer),
            #         "boost": -1
            #     }                
            # }
        ]
    }
}

results = es_client.search(index='recipe', query=query, size=100)
results_df = pd.DataFrame([[hit["_source"]['Name'], hit["_source"]['Keywords'], hit["_source"]
['RecipeIngredientParts'], hit["_score"]] for hit in results['hits']['hits']], columns=['Name', 'Keywords', 'Ingredient', 
'score']).sort_values(by=['score'], ascending=True)

# results_df
print('Unprefer recipe score')
print(results_df.head().to_markdown())
print('Prefer recipe score')
print(results_df.tail().to_markdown())
# Out:
# Unprefer recipe score
# |    | Name                                    | Keywords                                                                                                                                                      | Ingredient                                                                                                                                                                                                  |   score |
# |---:|:----------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------:|
# | 99 | Sultana Bran Cookies                    | ['Beginner Cook', '< 30 Mins', 'Kid Friendly', 'Cookie & Brownie', 'Easy']                                                                                    | ['self raising flour', 'orange, rind of', 'brown sugar', 'white lily self-rising flour', 'raw sugar', 'bicarbonate of soda']                                                                                | 14.8084 |
# | 98 | Oatmeal Shortbread                      | ['Beginner Cook', '< 30 Mins', 'Kid Friendly', 'Christmas', 'European', 'Cookie & Brownie', 'For Large Groups', 'Scottish', 'Grains', 'Easy', 'Lunch/Snacks'] | ['vanilla', 'butter', 'brown sugar', 'rolled oats', 'flour', 'baking soda']                                                                                                                                 | 14.8441 |
# | 97 | Sticky Date Cupcakes With Caramel Icing | ['From Scratch', 'Kid Friendly', 'Baking', '< 60 Mins', 'Low Protein', 'Australian', 'For Large Groups', 'Oven']                                              | ['brown sugar', 'dark brown sugar', 'icing sugar', 'eggs', 'boiling water', 'raw sugar', 'unsalted butter', 'self-raising flour', 'demerara sugar', 'bicarbonate of soda', 'pitted dates', 'ground ginger'] | 14.9142 |
# | 96 | Viennese Biscuits (Cookies)             | ['Cookie & Brownie', '< 60 Mins', 'Austrian', 'European', 'For Large Groups', 'Easy']                                                                         | ['icing sugar', 'butter', 'plain flour']                                                                                                                                                                    | 14.944  |
# | 95 | Healthy Apple Energy Loaf               | ['Beginner Cook', 'Easy', 'Lactose Free', 'Free Of...', 'Egg Free', 'Oven', 'Low Cholesterol', '< 60 Mins', 'Breads', 'Lunch/Snacks', 'Healthy']              | ['granny smith apples', 'baking powder', 'whole wheat flour', 'walnuts', 'bicarbonate of soda', 'dates', 'honey']                                                                                           | 14.9792 |
# Prefer recipe score
# |    | Name                          | Keywords                                                                                                                                  | Ingredient                                                                                                                                                     |   score |
# |---:|:------------------------------|:------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------|--------:|
# |  4 | Anzac Biscuits (Cookies)      | ['Inexpensive', 'Free Of...', 'Kid Friendly', 'Egg Free', 'Cookie & Brownie', '< 60 Mins', 'Australian', 'For Large Groups', 'Weeknight'] | ['butter', 'plain flour', 'brown sugar', 'rolled oats', 'golden syrup', 'boiling water', 'bicarbonate of soda', 'sugar']                                       | 52.2505 |
# |  3 | Anzac Biscuits                | ['< 30 Mins', 'Cookie & Brownie', 'Australian', 'Grains', 'Easy']                                                                         | ['butter', 'plain flour', 'lemon rind', 'rolled oats', 'golden syrup', 'boiling water', 'bicarbonate of soda', 'caster sugar']                                 | 52.7767 |
# |  2 | Tofu and Bok Choy Stir Fry    | ['Vegan', '< 15 Mins', 'Chinese', 'Vegetable', 'Low Cholesterol', 'For Large Groups', 'Asian', 'Beans', 'Healthy']                        | ['bok choy', 'low sodium soy sauce', 'extra firm tofu', 'fresh ginger', 'dry sherry', 'green onions', 'garlic cloves', 'dry crushed red pepper', 'cornstarch'] | 54.3689 |
# |  1 | Anzac Biscuits                | ['Beginner Cook', 'Inexpensive', '< 60 Mins', 'For Large Groups', 'Easy']                                                                 | ['butter', 'plain flour', 'coconut', 'rolled oats', 'golden syrup', 'boiling water', 'bicarbonate of soda', 'sugar']                                           | 54.91   |
# |  0 | Healthy Vegetable Tofu Kebabs | ['< 30 Mins', 'Peppers', 'Vegetable', 'Beans']                                                                                            | ['firm tofu', 'salt', 'green pepper', 'button mushrooms', 'lemon juice', 'honey', 'zucchini', 'cherry tomatoes']                                               | 70.6026 |

# %%
user = users.find_one({'_id': ObjectId('65f017e507c1a9b66d854764')})
queries = []

prefer = set(user['interestedCategory']) # boost up

un_prefer = set(user['uninterestedCategory']) -  prefer # boost down

if len(user['interestedCategory']) > 0:
    queries.append(
        {
            
            "boosting": {
                "positive" : {
                    "match": {"Keywords": ' '.join(prefer)},
                },
                "negative": {
                    "match": {"Keywords": ' '.join(un_prefer)}
                },
                "negative_boost": 0.5
            }
        
    })

else:
    queries.append({
        "function_score": {
            "query": {"match_all": {}},
            "random_score": {}
        }
    })

if len(user['interestedRecipe']) > 0:
    like = []
    for recipe in user['interestedRecipe']:
        like.append({'_id': recipe})
    queries.append({
        'more_like_this': {
            "fields": ["Name", "Keywords", "RecipeIngredientParts", "RecipeCategory"],
            "like": like, "min_term_freq": 1, "min_doc_freq": 5, "max_query_terms": 20,
            'boost': 1
        }
    })


query = {"dis_max": {
        "queries": queries
}}

query
# Out:
# {'dis_max': {'queries': [{'boosting': {'positive': {'match': {'Keywords': 'Oven Beginner Cook Easy'}},
#      'negative': {'match': {'Keywords': 'Australian Freezer'}},
#      'negative_boost': 0.5}},
#    {'more_like_this': {'fields': ['Name',
#       'Keywords',
#       'RecipeIngredientParts',
#       'RecipeCategory'],
#      'like': [{'_id': '65d5e49a8598535be43ee02b'},
#       {'_id': '65d5e49a8598535be43ee18a'},
#       {'_id': '65d5e48f8598535be43ebdc9'},
#       {'_id': '65d5e4918598535be43ec36a'},
#       {'_id': '65d5e48e8598535be43eb9f0'},
#       {'_id': '65d5e4998598535be43edcd9'},
#       {'_id': '65d5e49f8598535be43ef357'},
#       {'_id': '65d5e49d8598535be43eed42'},
#       {'_id': '65d5e4988598535be43eda42'}],
#      'min_term_freq': 1,
#      'min_doc_freq': 5,
#      'max_query_terms': 20,
#      'boost': 1}}]}}

# %%
results = es_client.search(index='recipe', query=query, size=100)
results_df = pd.DataFrame([[hit["_source"]['Name'], hit["_source"]['Keywords'], hit["_source"]
['RecipeIngredientParts'], hit["_score"]] for hit in results['hits']['hits']], columns=['Name', 'Keywords', 'Ingredient', 
'score']).sort_values(by=['score'], ascending=False)

results_df
# Out:
#                                  Name  \
# 0   Sammy's Beef and Sausage Meatloaf
# 2     Crab Casserole (Chinese Buffet)
# 3                  Bea's Banana Bread
# 4                        Salmon Puffs
# 5                       Cod Vera Cruz
# ..                                ...
# 91    Cinn-ful Fudgy Rum Pudding Cake
# 90                        Spoon Rolls
# 89          Creamy Lemon Meringue Pie
# 87                        BBQ Muffins
# 99       Sour Cream Blueberry Muffins
#
#                                              Keywords  \
# 0              [Easy, Oven, Beginner Cook, < 4 Hours]
# 2              [Easy, Oven, Beginner Cook, < 60 Mins]
# 3              [Easy, Oven, Beginner Cook, < 4 Hours]
# 4              [Easy, Oven, Beginner Cook, < 60 Mins]
# 5              [Easy, Oven, Beginner Cook, < 30 Mins]
# ..                                                ...
# 91  [Beginner Cook, Kid Friendly, Low Protein, Eas...
# 90  [Beginner Cook, Inexpensive, Brunch, < 30 Mins...
# 89  [Beginner Cook, < 30 Mins, Spring, Summer, Fru...
# 87  [Beginner Cook, < 30 Mins, Easy, Meat, Kid Fri...
# 99  [Beginner Cook, Brunch, < 30 Mins, Easy, For L...
#
#                                            Ingredient     score
# 0   [garlic powder, water, ketchup, seasoning salt...  7.335291
# 2   [butter, salt, onions, parsley, lump crabmeat,...  7.335291
# 3   [bananas, Miracle Whip, egg, baking soda, flou...  7.335291
# 4   [salmon, garlic powder, salt, eggs, parsley, l...  7.335291
# 5   [garlic powder, condensed chicken broth, dried...  7.335291
# ..                                                ...       ...
# 91  [butter, salt, cocoa powder, ground cloves, va...  5.728935
# 90  [dry yeast, margarine, egg, self rising flour,...  5.728935
# 89  [eggs, cream of tartar, lemon juice, sweetened...  5.728935
# 87  [brown sugar, cider vinegar, chili powder, ket...  5.728935
# 99  [nutmeg, salt, eggs, sugar, sour cream, fresh ...  5.728935
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Ranking evaluation

# %%
query = {
   "more_like_this":{
        "fields":["Name", "Keywords", "RecipeIngredientParts", "RecipeCategory"],"like":[{"_id": "65d5e4928598535be43ec8fc"}],"min_term_freq":1,"min_doc_freq":5,"max_query_terms":20
    }
}

ratings = [
     { "_index": "recipe", "_id": "65d5e4928598535be43ec668", "rating": 0 },
     { "_index": "recipe", "_id": "65d5e48e8598535be43eba08", "rating": 3 },
     { "_index": "recipe", "_id": "65d5e4918598535be43ec3eb", "rating": 0 },
     { "_index": "recipe", "_id": "65d5e4928598535be43ec8fc", "rating": 5 },
     { "_index": "recipe", "_id": "65d5e49a8598535be43ee0c9", "rating": 2 },
     { "_index": "recipe", "_id": "65d5e49a8598535be43ee26f", "rating": 1 },
     { "_index": "recipe", "_id": "65d5e49b8598535be43ee65e", "rating": 4 },
     { "_index": "recipe", "_id": "65d5e49b8598535be43ee374", "rating": 5 },
]

requests = [
    { "id": "Query_1", "request": {"query": query} , 'ratings': ratings}
]

metric =  {
    "dcg": {
      "k": 20,
      "normalize": False
    }
}

results = es_client.rank_eval(index='recipes', requests=requests, metric= metric)
# mertic_score_df = pd.DataFrame()

# mertic_score_df
results['metric_score']
# Out:
# 'NaN'

# %%
results_df = pd.DataFrame([[hit['hit']["_id"], hit['hit']["_score"], hit["rating"]] for hit in results['details']['Query_1']['hits']], columns=['ID', 'Score', 'Rating'])

results_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 results_df = pd.DataFrame([[hit['hit']["_id"], hit['hit']["_score"], hit["rating"]] for hit in results['details']['Query_1']['hits']], columns=['ID', 'Score', 'Rating'])
#       3 results_df
#
# KeyError: 'Query_1'
